# %% [markdown]
# ![dqn_full_plot.png](attachment:dqn_full_plot.png)

# %% [markdown]
# ### 平均奖励 (avg_reward) 分析
#
# 趋势：平均奖励在训练初期波动较大，但在大约 30,000 步后趋于稳定，最终达到约 270-280 的水平。
#
# 稳定性：从第 30,000 步开始，平均奖励基本保持在一个较高的水平，表明模型已经学会了有效的策略来最大化奖励。

# %% [markdown]
# ### 成功率 (success_rate) 分析
#
# 趋势：成功率在训练过程中表现出明显的波动，尤其是在早期阶段。然而，在后期阶段，成功率逐渐提高并稳定在 0.94-0.96 的范围内。
#
# 稳定性：尽管存在一些波动，但总体上成功率呈现上升趋势，并且在最后几轮评估中达到了较高的水平，说明模型能够有效地完成任务。

# %% [markdown]
# ### 探索率 (epsilon) 分析
#
# 趋势：探索率从初始值 1.0 逐渐衰减到接近 0.01 的最小值。这表明模型在训练过程中逐步减少了随机探索，转而更多地依赖于已学到的策略。
#
# 影响：随着探索率的降低，模型的行为变得更加确定性，有助于巩固和优化已学得的策略。

# %% [markdown]
# ## <center> 综合评价

# %% [markdown]
# 收敛性：模型在训练后期表现出良好的收敛性，平均奖励和成功率均趋于稳定。
#
# 性能：最终的平均奖励约为 270-280，成功率约为 0.94-0.96，表明模型在大多数情况下能够成功完成任务，并获得较高的奖励。
#
# 改进空间：虽然模型表现良好，但仍有一些波动，特别是在成功率方面。可以通过调整超参数（如学习率、批量大小等）或改进奖励函数来进一步提升性能。
